# %% [markdown]
# # Question 1:
# - Proving if Zipf's law works in Natural Language using glob, matploblib and functions

# %%
import nltk.corpus
import glob
import csv
import math
import matplotlib.pyplot as plt

# %%
from nltk.corpus import reuters

# %%
#reuters.fileids()[:15]

# %%
#for file in reuters.fileids()[:15]:
#taking all the files starting from "100" in reuters/training
len(glob.glob('/Users/reuters/training/100*'))
# Out:
# 64

# %%
words=[]
count={}
#Using files starting from '100' under the training set in reuters corpura 
for name in glob.glob('/Users/reuters/training/100*'):
    #print(reuters.words(name)) #for words in reuters.words(name)
    [words.append(word.lower()) for word in reuters.words(name) if word.isalpha()]
print(words)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\kamal\Anaconda3\lib\site-packages\nltk\data.py in __init__(self, zipfile, entry)
#     476             try:
# --> 477                 zipfile.getinfo(entry)
#     478             except Exception:
#
# C:\Users\kamal\Anaconda3\lib\zipfile.py in getinfo(self, name)
#    1198             raise KeyError(
# -> 1199                 'There is no item named %r in the archive' % name)
#    1200
#
# KeyError: "There is no item named 'reuters/Users/reuters/training/100' in the archive"
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-004218a71d33> in <module>()
#       4 for name in glob.glob('/Users/reuters/training/100*'):
#       5     #print(reuters.words(name)) #for words in reuters.words(name)
# ----> 6     [words.append(word.lower()) for word in reuters.words(name) if word.isalpha()]
#       7 print(words)
#
# C:\Users\kamal\Anaconda3\lib\site-packages\nltk\corpus\reader\plaintext.py in words(self, fileids, categories)
#     166     def words(self, fileids=None, categories=None):
#     167         return PlaintextCorpusReader.words(
# --> 168             self, self._resolve(fileids, categories))
#     169     def sents(self, fileids=None, categories=None):
#     170         return PlaintextCorpusReader.sents(
#
# C:\Users\kamal\Anaconda3\lib\site-packages\nltk\corpus\reader\plaintext.py in words(self, fileids)
#      87         return concat([self.CorpusView(path, self._read_word_block, encoding=enc)
#      88                        for (path, enc, fileid)
# ---> 89                        in self.abspaths(fileids, True, True)])
#      90
#      91     def sents(self, fileids=None):
#
# C:\Users\kamal\Anaconda3\lib\site-packages\nltk\corpus\reader\api.py in abspaths(self, fileids, include_encoding, include_fileid)
#     188             fileids = [fileids]
#     189
# --> 190         paths = [self._root.join(f) for f in fileids]
#     191
#     192         if include_encoding and include_fileid:
#
# C:\Users\kamal\Anaconda3\lib\site-packages\nltk\corpus\reader\api.py in <listcomp>(.0)
#     188             fileids = [fileids]
#     189
# --> 190         paths = [self._root.join(f) for f in fileids]
#     191
#     192         if include_encoding and include_fileid:
#
# C:\Users\kamal\Anaconda3\lib\site-packages\nltk\data.py in join(self, fileid)
#     521     def join(self, fileid):
#     522         entry = '%s/%s' % (self._entry, fileid)
# --> 523         return ZipFilePathPointer(self._zipfile, entry)
#     524
#     525     def __repr__(self):
#
# C:\Users\kamal\Anaconda3\lib\site-packages\nltk\compat.py in _decorator(*args, **kwargs)
#     559     def _decorator(*args, **kwargs):
#     560         args = (args[0], add_py3_data(args[1])) + args[2:]
# --> 561         return init_func(*args, **kwargs)
#     562     return wraps(init_func)(_decorator)
#     563
#
# C:\Users\kamal\Anaconda3\lib\site-packages\nltk\data.py in __init__(self, zipfile, entry)
#     487                     # Otherwise, complain.
#     488                     raise IOError('Zipfile %r does not contain %r' %
# --> 489                                   (zipfile.filename, entry))
#     490         self._zipfile = zipfile
#     491         self._entry = entry
#
# OSError: Zipfile 'C:\\Users\\kamal\\AppData\\Roaming\\nltk_data\\corpora\\reuters.zip' does not contain 'reuters/Users/reuters/training/100'

# %%
for word in words:
    count[word]=count.get(word,0)+1
sorted_list=sorted(count.items(), key=lambda x: x[1])
list= sorted(sorted_list,key=lambda x: x[1],reverse=True)
print(list)
# Out:
# [('the', 293), ('of', 174), ('to', 148), ('said', 140), ('in', 112), ('vs', 99), ('a', 99), ('and', 92), ('mln', 78), ('lt', 69), ('loss', 69), ('cts', 68), ('s', 67), ('it', 60), ('for', 54), ('year', 52), ('dlrs', 48), ('its', 46), ('net', 45), ('that', 45), ('is', 43), ('pct', 41), ('by', 38), ('company', 35), ('inc', 35), ('from', 35), ('oil', 33), ('not', 33), ('be', 32), ('he', 31), ('will', 31), ('on', 31), ('with', 30), ('shr', 30), ('profit', 30), ('bank', 28), ('as', 26), ('u', 25), ('stock', 25), ('would', 23), ('bp', 23), ('corp', 22), ('billion', 22), ('revs', 22), ('was', 22), ('an', 21), ('we', 20), ('at', 20), ('share', 20), ('have', 20), ('are', 19), ('quarter', 19), ('has', 18), ('unit', 18), ('standard', 17), ('qtr', 17), ('they', 17), ('first', 16), ('had', 16), ('which', 16), ('offer', 15), ('two', 15), ('financial', 15), ('also', 14), ('heller', 14), ('six', 14), ('one', 14), ('april', 14), ('more', 13), ('dividend', 13), ('were', 13), ('note', 13), ('market', 12), ('co', 12), ('holding', 12), ('price', 11), ('british', 11), ('current', 11), ('this', 11), ('shares', 11), ('sales', 10), ('national', 10), ('bid', 10), ('pemberton', 10), ('or', 10), ('sale', 10), ('cubic', 10), ('board', 10), ('leigh', 10), ('but', 10), ('record', 10), ('i', 10), ('rose', 10), ('chairman', 10), ('meters', 9), ('pillsbury', 9), ('operations', 9), ('been', 9), ('dollar', 9), ('than', 9), ('dlr', 9), ('their', 9), ('imports', 9), ('analysts', 9), ('exchange', 9), ('held', 9), ('bales', 9), ('banks', 9), ('per', 9), ('level', 9), ('today', 9), ('nine', 8), ('k', 8), ('split', 8), ('new', 8), ('shareholders', 8), ('did', 8), ('tonnes', 8), ('after', 8), ('american', 8), ('about', 8), ('petroleum', 8), ('sees', 7), ('qtly', 7), ('div', 7), ('earlier', 7), ('does', 7), ('group', 7), ('think', 7), ('fall', 7), ('over', 7), ('before', 7), ('cash', 7), ('last', 7), ('services', 7), ('december', 7), ('japanese', 7), ('total', 7), ('ec', 7), ('says', 7), ('up', 7), ('appropriate', 7), ('stg', 7), ('tax', 7), ('five', 7), ('compared', 7), ('if', 6), ('prices', 6), ('gould', 6), ('plan', 6), ('pay', 6), ('around', 6), ('other', 6), ('merger', 6), ('gain', 6), ('production', 6), ('report', 6), ('against', 6), ('earnings', 6), ('higher', 6), ('sets', 6), ('federated', 6), ('while', 6), ('world', 6), ('banking', 6), ('expects', 6), ('terms', 6), ('four', 6), ('viacom', 6), ('announced', 6), ('ended', 6), ('week', 6), ('rates', 6), ('federal', 6), ('approved', 6), ('common', 6), ('fair', 6), ('end', 6), ('may', 6), ('french', 6), ('includes', 5), ('nations', 5), ('publications', 5), ('into', 5), ('units', 5), ('strong', 5), ('ago', 5), ('companies', 5), ('all', 5), ('sell', 5), ('shrs', 5), ('discontinued', 5), ('received', 5), ('out', 5), ('cable', 5), ('markets', 5), ('credit', 5), ('capital', 5), ('revenues', 5), ('crop', 5), ('march', 5), ('trading', 5), ('no', 5), ('avg', 5), ('such', 5), ('quantech', 5), ('years', 5), ('falling', 5), ('simon', 5), ('volvo', 5), ('previously', 5), ('agreement', 5), ('vice', 5), ('entertainment', 5), ('losses', 5), ('public', 5), ('there', 5), ('states', 5), ('exports', 5), ('added', 5), ('increase', 5), ('sold', 5), ('told', 5), ('barrel', 5), ('accord', 5), ('products', 5), ('assets', 5), ('executive', 5), ('prior', 5), ('users', 5), ('final', 5), ('paris', 5), ('england', 5), ('natural', 4), ('again', 4), ('now', 4), ('nil', 4), ('funds', 4), ('term', 4), ('act', 4), ('insurance', 4), ('only', 4), ('energy', 4), ('under', 4), ('planned', 4), ('gasoline', 4), ('additional', 4), ('minnesota', 4), ('acquisition', 4), ('early', 4), ('wireless', 4), ('full', 4), ('believe', 4), ('reserve', 4), ('going', 4), ('special', 4), ('when', 4), ('plans', 4), ('rogers', 4), ('letter', 4), ('previous', 4), ('president', 4), ('partnership', 4), ('can', 4), ('savings', 4), ('analyst', 4), ('second', 4), ('committee', 4), ('limited', 4), ('chief', 4), ('thatcher', 4), ('flow', 4), ('interests', 4), ('slightly', 4), ('cen ...

# %%
count=1
with open('data.csv', 'w') as csvfile:
    rows=['Word1','Rank','Frequency']
    writer = csv.writer(csvfile)
    writer.writerow(['Word','Rank','Frequency'])
    for item in list:
        writer.writerow([item[0],count,item[1]])  #sucessfully written sorted data according to rank to csv file 
        count+=1

# %%
x=[]
y=[]
with open('data.csv','r') as file:
    reader=csv.reader(file)
    next(reader,None) #Ignoring the headers from the csv file
    for row in reader:
        x.append(math.log10(int(row[1])))
        y.append(math.log10(int(row[2])))
plt.plot(x,y)
plt.xlabel('Log-Rank')
plt.ylabel('Log-Frequency')
plt.title("Zipf's Law")
plt.show()

# %% [markdown]
# # Conclusion -
# - The above graph shows that the curve between Log(Frequency) vs Log(Rank) graph is almost a straight line with a slope of -1. Hence, proving the Zipf's Law.
